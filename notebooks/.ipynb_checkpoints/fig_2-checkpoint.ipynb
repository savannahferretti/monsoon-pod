# %%
import warnings
import numpy as np
import xarray as xr
import proplot as pplt
pplt.rc.reso='hi'
warnings.filterwarnings('ignore')

# %%
FILEDIR = '/ocean/projects/atm200007p/sferrett/Repos/monsoon-pr/data/processed'
SAVEDIR = '/ocean/projects/atm200007p/sferrett/Repos/monsoon-pr/figs'
CASES   = [(6,'June','#28d0b8'),(7,'July','#268d9c'),(8,'August','#2d2f45')]
# NUMTHRESH = 10

# %%
def open_dataset(filename,filedir=FILEDIR):
    filepath = f'{filedir}/{filename}'
    ds = xr.open_dataset(filepath)
    return ds

ds = open_dataset('binned_stats.nc')

# %%
def get_bin_mean_pr(monthstats,numthresh=NUMTHRESH):
    Q0 = monthstats.Q0
    Q1 = monthstats.Q1
    Q0[Q0==0.0] = np.nan
    Q = Q1/Q0
    # Q[Q<numthresh] = np.nan
    return Q

# %%
regions = ds.region.values
months  = ds.month.values
fig,axs = pplt.subplots(nrows=1,ncols=4,share=True,span=True)
axs.format(collabels=['Eastern Arabian Sea','Central India','Northern Bay of Bengal','Central Bay of Bengal'],
           xlabel='$\mathit{B_L}$ (m/s$^2$)',xlim=(-0.4,0.1),xticks=0.1,
           ylabel='Precipitation (mm/day)',ylim=(0,1200),yticks=200)
for i,region in enumerate(regions):
    regiondata = ds.sel(region=region)
    for month,label,color in CASES:
        monthdata = regiondata.sel(month=month)
        y = get_bin_mean_pr(monthdata)
        axs[i].scatter(monthdata.bl,y,color=color,alpha=0.5,label=label)
axs[0].legend(loc='ul',ncols=1)
pplt.show()
fig.save(f'{SAVEDIR}/fig_2.png',dpi=300)
# Out:
# Figure(nrows=1, ncols=4, refwidth=2.5)
