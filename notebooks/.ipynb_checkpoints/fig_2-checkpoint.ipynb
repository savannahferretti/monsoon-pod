# %%
import warnings
import numpy as np
import xarray as xr
import proplot as pplt
pplt.rc.reso='hi'
warnings.filterwarnings('ignore')

# %%
REGIONS   = {
    'Eastern Arabian Sea':{'latmin':9.,'latmax':19.5,'lonmin':64.,'lonmax':72.}, 
    'Central India':{'latmin':18.,'latmax':24.,'lonmin':76.,'lonmax':83.},
    'Central Bay of Bengal':{'latmin':9.,'latmax':14.5,'lonmin':86.5,'lonmax':90.},
    'Equatorial Indian Ocean':{'latmin':5.,'latmax':10.,'lonmin':62.,'lonmax':67.5},
    'Konkan Coast':{'latmin':15.,'latmax':19.5,'lonmin':69.,'lonmax':72.5}} 
FILEDIR = '/ocean/projects/atm200007p/sferrett/Repos/monsoon-pr/data/processed'
SAVEDIR = '/ocean/projects/atm200007p/sferrett/Repos/monsoon-pr/figs'
CASES   = [(6,'June','#D42028'),(7,'July','#F2C85E'),(8,'August','#5BA7DA')]
SAMPLETHRESH = 50

# %%
def open_dataset(filename,filedir=FILEDIR):
    filepath = f'{filedir}/{filename}'
    ds = xr.open_dataset(filepath)
    return ds

data = open_dataset('binned_stats.nc')

# %%
def get_bin_mean_pr(stats,bintype,samplethresh=SAMPLETHRESH):
    if bintype=='1D':
        Q0 = stats.Q0.values
        Q1 = stats.Q1.values
        Q0[Q0==0.0] = np.nan
        Q = Q1/Q0
        Q[Q0<samplethresh] = np.nan
        return Q
    if bintype=='2D':
        P0 = stats.P0.values
        P1 = stats.P1.values
        P0[P0==0.0] = np.nan
        P = P1/P0
        P[P0<samplethresh] = np.nan
        return P

def get_precipitating_pdf(stats,bintype='1D',samplethresh=SAMPLETHRESH):
    if bintype=='1D':
        Q0 = stats.Q0.values
        QE = stats.QE.values
        Q0[Q0==0.0] = np.nan
        QE[Q0<samplethresh] = np.nan
        return QE
    if bintype=='2D':
        P0 = stats.P0.values
        PE = stats.PE.values
        P0[P0==0.0] = np.nan
        PE[P0<samplethresh] = np.nan        
        return PE

# %%
CASES = {
    'JJ':[(6,'June','#D42028'),(7,'July','#F2C85E')],
    'JA':[(7,'July','#F2C85E'),(8,'August','#5BA7DA')]}

prkwargs = dict(marker='o',alpha=0.8,s=100)
blkwargs = dict(marker='D',alpha=0.1,s=20,zorder=0)

# %%
fig,axs = pplt.subplots(nrows=1,ncols=len(REGIONS),refwidth=2)
axs.format(xlabel='$\mathit{B_L}$ (m/s$^2$)',xlim=(-0.34,0.04),xticks=0.1,
           ylabel='Precipitation (mm/day)',ylim=(-10,500),yticks=100)

for i,region in enumerate(data.region.values):
    ax = axs[i]
    ax.format(titleloc='c',title=f'{region}')
    bx = ax.twinx()
    bx.format(yscale='log',ylim=(10,10e5))
    if i == len(REGIONS)-1:
        bx.format(yformatter='log',ylabel='Density')
    else:
        bx.format(yticklabels=[])
    casekey = 'JJ' if i<3 else 'JA'
    axnum   = 0 if casekey=='JJ' else 3
    for month,label,color in CASES[casekey]:
        monthdata = data.sel(region=region,month=month)
        x = monthdata.bl.values
        y = get_bin_mean_pr(monthdata,bintype='1D')
        twiny = get_precipitating_pdf(monthdata,bintype='1D')
        bx.scatter(x,twiny,color=color,**blkwargs)
        ax.scatter(x,y,color=color,label=label,**prkwargs)
    axs[axnum].legend(loc='ul',ncols=1)

pplt.show()
# fig.save(f'{SAVEDIR}/fig_2.png',dpi=600)
# Out:
# Figure(nrows=1, ncols=5, refwidth=2.0)
